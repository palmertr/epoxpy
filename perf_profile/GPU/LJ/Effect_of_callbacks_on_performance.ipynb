# %%
import numpy.random as rd
import math
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
t_n = [1,10,100,1000]
tps = [17.3962,176.096,1003.02,2157.39]

plt.xlabel('callback period [time steps]')
plt.ylabel('TPS')
plt.axhline(y=2490.5, linewidth=2, color = 'r',label='wo callback')
plt.legend()
plt.plot(t_n,tps,marker='o',label='w callback')
# Out:
# /Users/stephenthomas/miniconda3/envs/epoxpy_env/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
